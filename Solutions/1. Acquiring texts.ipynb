# %%
from tdmh import *

# %% [markdown]
# # Exercises
#
# ## Exercise 1.1
#
# 1. Download all the text files that are listed in the following dictionary.
#
# `
#     gutenberg_files = {
#     'https://www.gutenberg.org/files/98/98-0.txt' :
#         'A Tale of Two Cities',
#     'https://www.gutenberg.org/files/580/580-0.txt':
#         'The Pickwick Papers'
#    }
# `
#
# Save these files in a folder named 'Texts'. In Python, you can make new folders using the `os` package, as follows:
#
# `
# os.mkdir('Texts')
# `

# %%
import os
import requests
import re

gutenberg_files = {
    'https://www.gutenberg.org/files/98/98-0.txt' :
        'A Tale of Two Cities',
    'https://www.gutenberg.org/files/580/580-0.txt':
        'The Pickwick Papers'
   }

dir = 'Texts'
if not os.path.exists(dir): 
    os.mkdir(dir)
    
#os.mkdir(dir)


for url in gutenberg_files:
    print("Downloading " + gutenberg_files[url] + " ...")
    response = requests.get(url)
    title = re.sub( r'\s+' , '_' ,  gutenberg_files[url] )

    if response:
        response.encoding = 'utf-8'
        full_text = remove_pg_boilerplate(response.text)      
        
        path = os.path.join( dir , f'{title}.txt' )
        out = open( path , 'w' , encoding = 'utf-8')

        out.write( full_text.strip() )
        out.close()

print('\nDone!')
# Out:
# Downloading A Tale of Two Cities ...
# Downloading The Pickwick Papers ...
#
# Done!

# %% [markdown]
# ## Exercise 1.2.
#
# Potentially, you can acquire texts using Web Scraping.
#
# The webpage below offers access to the complete work of H.P. Lovecraft.
# http://www.hplovecraft.com/writings/texts/
#
# Can you write code in Python to download all the texts that are listed on this page?

# %%
from bs4 import BeautifulSoup
import requests
import re


dir = 'Lovecraft'
if not os.path.exists(dir): 
    os.mkdir(dir)

baseUrl = "http://www.hplovecraft.com/writings/texts/"

soup = ""

response = requests.get( baseUrl )

soup = BeautifulSoup( response.text ,"lxml")
links = soup.find_all("a")


for l in links:

    if l.get("href") is not None:
        
        ## The body of <a> contains the title 
        if l.string is not None:
            linktext = l.string
        else:
            linktext = l.get("href")
            linktext = linktext[ linktext.rindex('/') + 1 : ]
            linktext = re.sub( r'[.]aspx' , '' , linktext )
            
        textUrl = baseUrl + l.get("href")

        if re.search( 'fiction' , textUrl ):
            print(f"{linktext}: {textUrl}")
            response = requests.get( textUrl )
            soup = BeautifulSoup( response.text ,"lxml")
            body = soup.find("body")

            fullText = body.get_text()
            fullText = re.sub( 'By H. P. Lovecraft' , ' by H. P. Lovecraft ' , fullText )

            fullText = fullText[fullText.index('About This Site') + 15 : ]
            fullText = fullText[ 0 : fullText.rindex('Return to ') ]
            fullText = fullText.strip()
            
            path = os.path.join( dir , linktext + '.txt' )

            out = open( path , 'w' , encoding = 'utf-8' )
            out.write( fullText )
            out.close()
# Out:
# Fiction: http://www.hplovecraft.com/writings/texts/#fiction
# The Alchemist: http://www.hplovecraft.com/writings/texts/fiction/a.aspx
# Ashes: http://www.hplovecraft.com/writings/texts/fiction/as.aspx
# At the Mountains of Madness: http://www.hplovecraft.com/writings/texts/fiction/mm.aspx
# Azathoth: http://www.hplovecraft.com/writings/texts/fiction/az.aspx
# The Battle that Ended the Century: http://www.hplovecraft.com/writings/texts/fiction/bec.aspx
# The Beast in the Cave: http://www.hplovecraft.com/writings/texts/fiction/bc.aspx
# Beyond the Wall of Sleep: http://www.hplovecraft.com/writings/texts/fiction/bws.aspx
# The Book: http://www.hplovecraft.com/writings/texts/fiction/b.aspx
# The Call of Cthulhu: http://www.hplovecraft.com/writings/texts/fiction/cc.aspx
# The Case of Charles Dexter Ward: http://www.hplovecraft.com/writings/texts/fiction/cdw.aspx
# The Cats of Ulthar: http://www.hplovecraft.com/writings/texts/fiction/cu.aspx
# Celephaïs: http://www.hplovecraft.com/writings/texts/fiction/c.aspx
# The Challenge from Beyond: http://www.hplovecraft.com/writings/texts/fiction/cb.aspx
# Collapsing Cosmoses: http://www.hplovecraft.com/writings/texts/fiction/clc.aspx
# The Colour out of Space: http://www.hplovecraft.com/writings/texts/fiction/cs.aspx
# Cool Air: http://www.hplovecraft.com/writings/texts/fiction/ca.aspx
# The Crawling Chaos: http://www.hplovecraft.com/writings/texts/fiction/crc.aspx
# The Curse of Yig: http://www.hplovecraft.com/writings/texts/fiction/cy.aspx
# Dagon: http://www.hplovecraft.com/writings/texts/fiction/d.aspx
# Deaf, Dumb, and Blind: http://www.hplovecraft.com/writings/texts/fiction/ddb.aspx
# The Descendant: http://www.hplovecraft.com/writings/texts/fiction/de.aspx
# The Diary of Alonzo Typer: http://www.hplovecraft.com/writings/texts/fiction/dat.aspx
# The Disinterment: http://www.hplovecraft.com/writings/texts/fiction/di.aspx
# The Doom That Came to Sarnath: http://www.hplovecraft.com/writings/texts/fiction/ds.aspx
# The Dream-Quest of Unknown Kadath: http://www.hplovecraft.com/writings/texts/fiction/dq.aspx
# The Dreams in the Witch House: http://www.hplovecraft.com/writings/texts/fiction/dwh.aspx
# The Dunwich Horror: http://www.hplovecraft.com/writings/texts/fiction/dh.aspx
# The Electric Executioner: http://www.hplovecraft.com/writings/texts/fiction/ee.aspx
# The Evil Clergyman: http://www.hplovecraft.com/writings/texts/fiction/ec.aspx
# Ex Oblivione: http://www.hplovecraft.com/writings/texts/fiction/eo.aspx
# Facts concerning the Late Arthur Jermyn and His Family: http://www.hplovecraft.com/writings/texts/fiction/faj.aspx
# The Festival: http://www.hplovecraft.com/writings/texts/fiction/f.aspx
# From Beyond: http://www.hplovecraft.com/writings/texts/fiction/fb.aspx
# The Ghost-Eater: http://www.hplovecraft.com/writings/texts/fiction/ge.aspx
# The Green Meadow: http://www.hplovecraft.com/writings/texts/fiction/gm.aspx
# The Haunter of the Dark: http://www.hplovecraft.com/writings/texts/fiction/hd.aspx
# He: http://www.hplovecraft.com/writings/texts/fiction/he.aspx
# Herbert West—Reanimator: http://www.hplovecraft.com/writings/texts/fiction/hwr.aspx
# hn: http://www.hplovecraft.com/writings/texts/fiction/hn.aspx
# The Hoard of the Wizard-Beast: http://www.hplovecraft.com/writings/texts/fiction/hwb.aspx
# The Horror at Martin’s Beach: http://www.hplovecraft.com/writings/texts/fiction/hmb.aspx
# The Horror at Red Hook: http://www.hplovecraft.com/writings/texts/fiction/hrh.aspx
# The Horror in the Burying-Ground: http://www.hplovecraft.com/writings/texts/fiction/hb.aspx
# The Horror in the Museum: http://www.hplovecraft.com/writings/texts/fiction/hm.aspx
# The Hound: http://www.hplovecraft.com/writings/texts/fiction/h.aspx
# Hypnos: http://www.hplovecraft.com/writings/texts/fiction/hy.aspx
# Ibid: http://www.hplovecraft.com/writings/texts/fiction/ibid.aspx
# In the Vault: http://www.hplovecraft.com/writings/texts/fiction/iv.aspx
# In the Walls of Eryx: http://www.hplovecraft.com/writings/texts/fiction/iwe.aspx
# The Last Test: http://www.hplovecraft.com/writings/texts/fiction/lt.aspx
# The Little Glass Bottle: http://www.hplovecraft.com/writings/texts/fiction/lgb.aspx
# The Loved Dead: http://www.hplovecraft.com/writings/texts/fiction/ld.aspx
# The Lurking Fear: http://www.hplovecraft.com/writings/texts/fiction/lf.aspx
# The Man of Stone: http://www.hplovecraft.com/writings/texts/fiction/ms.aspx
# Medusa’s Coil: http://www.hplovecraft.com/writings/texts/fiction/mc.aspx
# Memory: http://www.hplovecraft.com/writings/texts/fiction/m.aspx
# The Moon-Bog: http://www.hplovecraft.com/writings/texts/fiction/mb.aspx
# The Mound: http://www.hplovecraft.com/writings/texts/fiction/mo.aspx
# The Music of Erich Zann: http://www.hplovecraft.com/writings/texts/fiction/mez.aspx
# The Mysterious Ship: http://www.hplovecraft.com/writings/texts/fiction/mys.aspx
# The Mystery of the Grave-Yard: http://www.hplovecraft.com/writings/texts/fiction/mg.aspx
# The Nameless City: http://www.hplovecraft.com/writings/texts/fiction/nc.aspx
# The Night Ocean: http://www.hplovecraft.com/writings/texts/fiction/no.aspx
# Nyarlathotep: http://www.hplovecraft.com/writings/texts/fiction/n.aspx
# Old Bugs: http://www.hplovecraft.com/writings/texts/fiction/ob.aspx
# The Other Gods: http://www.hplovecraft.com/writings/texts/fiction/og.aspx
# Out of the Aeons: http://www.hplovecraft.com/writings/texts/fiction/oa.aspx
# The Outsider: http://www.hplovecraft.com/writings/texts/fiction/o.aspx
# Pickman’s Model: http://www.hplovecraft.com/writings/texts/fiction/pm.aspx
# The Picture in the House: http://www.hplovecraft.com/writings/texts/fiction/ph.aspx
# Poetry and the Gods: http://www.hplovecraft.com/writings/texts/fiction/pg.aspx
# Polaris: http://www.hplovecraft.com/writings/texts/fiction/p.aspx
# The Quest of Iranon: http://www.hplovecraft.com/writings/texts/fiction/qi.aspx
# The Rats in the Walls: http://www.hplovecraft.com/writings/texts/fiction/rw.aspx
# A Reminiscence of Dr. Samuel Johnson: http://www.hplovecraft.com/writings/texts/fiction/rdsj.aspx
# The Secret Cave or John Lees Adventure: http://www.hplovecraft.com/writings/texts/fiction/sc.aspx
# The Shadow out of Time: http://www.hplovecraft.com/writings/texts/fiction/sot.aspx
# The Shadow over Innsmouth: http://www.hplovecraft.com/writings/texts/fiction/soi.aspx
# Discarded Draft of The Shadow over Innsmouth: http://www.hplovecraft.com/writings/texts/fiction/soidd.aspx
# The Shunned House: http://www.hplovecraft.com/writings/texts/fiction/sh.aspx
# The Silver Key: http://www.hplovecraft.com/writings/texts/fiction/sk.aspx
# The Slaying of the Monster: http://www.hplovecraft.com/writings/texts/fiction/sm.aspx
# The Statement of Randolph Carter: http://www.hplovecraft.com/writings/texts/fiction/src.aspx
# The Strange High House in the Mist: http://www.hplovecraft.com/writings/texts/fiction/shh.aspx
# The Street: http://www.hplovecraft.com/writings/texts/fiction/s.aspx
# Sweet Ermengarde: http://www.hplovecraft.com/writings/texts/fiction/se.aspx
# The Temple: http://www.hplovecraft.com/writings/texts/fiction/te.aspx
# The Terrible Old Man: http://www.hplovecraft.com/writings/texts/fiction/tom.aspx
# The Thing in the Moonlight: http://www.hplovecraft.com/writings/texts/fiction/tm.aspx
# The Thing on the Doorstep: http://www.hplovecraft.com/writings/texts/fiction/td.aspx
# Through the Gates of the Silver Key: http://www.hplovecraft.com/writings/texts/fiction/tgsk.aspx
# “Till A’ the Seas”: http://www.hplovecraft.com/writings/texts/fiction/tas.aspx
# The Tomb: http://www.hplovecraft.com/writings/texts/fiction/t.aspx
# The Transition of Juan Romero: http://www.hplovecraft.com/writings/texts/fiction/tjr.aspx
# The Trap: http://www.hplovecraft.com/writings/texts/fiction/trap.aspx
# The Tree: http://www.hplovecraft.com/writings/texts/fiction/tr.aspx
# The Tree on the Hill: http://www.hplovecraft.com/writings/texts/fiction/th.aspx
# Two Black Bottles: http://www.hplovecraft.com/writings/texts/fiction/tbb.aspx
# Under the Pyramids: http://www.hplovecraft.com/writings/texts/fiction/up.aspx
# The Unnamable: http://www.hplovecraft.com/writings/texts/fiction/u.aspx
# The Very Old Folk: http://www.hplovecraft.com/writings/texts/fiction/vof.aspx
# What the Moon Brings: http://www.hplovecraft.com/writings/texts/fiction/wmb.aspx
# The Whisperer in Darkness: http://www.hplovecraft.com/writings/texts/fiction/wid.aspx
# The White Ship: http://www.hplovecraft.com/writings/texts/fiction/ws.aspx
# Winged Death: http://www.hplovecraft.com/writings/texts/fiction/wd.aspx
